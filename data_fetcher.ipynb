# %%
import requests
from dotenv import load_dotenv
import os
import json

# %%
def append_to_json(data, filename):
    try:
        with open(f"data/{filename}", "r") as f:
            existing = json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        existing = []
    
    # Create a set of existing SHA values for quick lookup
    existing_shas = {item['sha'] for item in existing if 'sha' in item}
    
    # Filter out new data that already exists in the file
    new_data = [
        item for item in data 
        if 'sha' in item and item['sha'] not in existing_shas
    ]
    if not new_data:
        print(f"No new data to append to {filename}")
        return
    
    existing.extend(new_data)
    
    with open(f"data/{filename}", "w") as f:
        json.dump(existing, f, indent=4)
    
    print(f"Appended {len(new_data)} new items to {filename}")

# %%
url = "https://api.github.com/repos/dev-Rutwik/Github_AI_Agent/commits"
load_dotenv()
bear_token = os.getenv('GITHUB_PERSONAL_ACCESS_TOKEN')

headers = {
    "Authorization": f"Bearer {bear_token}",
    "Accept": "application/vnd.github.v3+json"
}
try: 
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise an error for bad responses
    data = response.json()
    print("Data Fetched Successfully")
    print(data)
    simplified_data = []
    for i in data:
        simplified_data.append({
            "sha": i["sha"],
            "author": i["commit"]["author"]["name"],
            "date": i["commit"]["author"]["date"],
            "message": i["commit"]["message"]
        })
    # append_to_json(simplified_data, "commits.json")
        # print(simplified_data)
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")    
except ValueError as e:
    print(f"Error parsing JSON: {e}")
import json
# Out:
# Data Fetched Successfully
# [{'sha': '376c2140e1f70f6c574bcbdd04617c68a48aa187', 'node_id': 'C_kwDOPFBJ_toAKDM3NmMyMTQwZTFmNzBmNmM1NzRiY2JkZDA0NjE3YzY4YTQ4YWExODc', 'commit': {'author': {'name': 'Dev-Rutwik', 'email': 'rutwik2602@gmail.com', 'date': '2025-07-03T05:09:24Z'}, 'committer': {'name': 'Dev-Rutwik', 'email': 'rutwik2602@gmail.com', 'date': '2025-07-03T05:09:24Z'}, 'message': '"Added Data Summary for data Analysis Agent"', 'tree': {'sha': '001e01b9f4b88a760437388e855c9280930ebef2', 'url': 'https://api.github.com/repos/Dev-Rutwik/Github_AI_Agent/git/trees/001e01b9f4b88a760437388e855c9280930ebef2'}, 'url': 'https://api.github.com/repos/Dev-Rutwik/Github_AI_Agent/git/commits/376c2140e1f70f6c574bcbdd04617c68a48aa187', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}, 'url': 'https://api.github.com/repos/Dev-Rutwik/Github_AI_Agent/commits/376c2140e1f70f6c574bcbdd04617c68a48aa187', 'html_url': 'https://github.com/Dev-Rutwik/Github_AI_Agent/commit/376c2140e1f70f6c574bcbdd04617c68a48aa187', 'comments_url': 'https://api.github.com/repos/Dev-Rutwik/Github_AI_Agent/commits/376c2140e1f70f6c574bcbdd04617c68a48aa187/comments', 'author': {'login': 'Dev-Rutwik', 'id': 215499842, 'node_id': 'U_kgDODNhEQg', 'avatar_url': 'https://avatars.githubusercontent.com/u/215499842?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Dev-Rutwik', 'html_url': 'https://github.com/Dev-Rutwik', 'followers_url': 'https://api.github.com/users/Dev-Rutwik/followers', 'following_url': 'https://api.github.com/users/Dev-Rutwik/following{/other_user}', 'gists_url': 'https://api.github.com/users/Dev-Rutwik/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Dev-Rutwik/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Dev-Rutwik/subscriptions', 'organizations_url': 'https://api.github.com/users/Dev-Rutwik/orgs', 'repos_url': 'https://api.github.com/users/Dev-Rutwik/repos', 'events_url': 'https://api.github.com/users/Dev-Rutwik/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Dev-Rutwik/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'committer': {'login': 'Dev-Rutwik', 'id': 215499842, 'node_id': 'U_kgDODNhEQg', 'avatar_url': 'https://avatars.githubusercontent.com/u/215499842?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Dev-Rutwik', 'html_url': 'https://github.com/Dev-Rutwik', 'followers_url': 'https://api.github.com/users/Dev-Rutwik/followers', 'following_url': 'https://api.github.com/users/Dev-Rutwik/following{/other_user}', 'gists_url': 'https://api.github.com/users/Dev-Rutwik/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Dev-Rutwik/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Dev-Rutwik/subscriptions', 'organizations_url': 'https://api.github.com/users/Dev-Rutwik/orgs', 'repos_url': 'https://api.github.com/users/Dev-Rutwik/repos', 'events_url': 'https://api.github.com/users/Dev-Rutwik/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Dev-Rutwik/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'parents': [{'sha': 'f84af56ca8f32bdfebf2c626895b4ecf66a08d31', 'url': 'https://api.github.com/repos/Dev-Rutwik/Github_AI_Agent/commits/f84af56ca8f32bdfebf2c626895b4ecf66a08d31', 'html_url': 'https://github.com/Dev-Rutwik/Github_AI_Agent/commit/f84af56ca8f32bdfebf2c626895b4ecf66a08d31'}]}, {'sha': 'f84af56ca8f32bdfebf2c626895b4ecf66a08d31', 'node_id': 'C_kwDOPFBJ_toAKGY4NGFmNTZjYThmMzJiZGZlYmYyYzYyNjg5NWI0ZWNmNjZhMDhkMzE', 'commit': {'author': {'name': 'Dev-Rutwik', 'email': 'rutwik2602@gmail.com', 'date': '2025-07-02T14:16:49Z'}, 'committer': {'name': 'Dev-Rutwik', 'email': 'rutwik2602@gmail.com', 'date': '2025-07-02T14:16:49Z'}, 'message': '"Testing the workflow"', 'tree': {'sha': '71cca3261911953393464ec50c337819256dbcee', 'url': 'https://api.github.com/repos/Dev-Rutwik/Github_AI_Agen ...

# %%
def fetch_and_post_pull_request_files(repo_name,repo, pull_number,state,title,user,created,updated):
    """Fetches pull request files and appends them to a JSON file."""
    url = f"https://api.github.com/repos/{repo_name}/{repo}/pulls/{pull_number}/files"
    load_dotenv()
    bear_token = os.getenv('GITHUB_PERSONAL_ACCESS_TOKEN')

    headers = {
        "Authorization": f"Bearer {bear_token}",
        "Accept": "application/vnd.github.v3+json"
    }
    try: 
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an error for bad responses
        data = response.json()
        print("Data Fetched Successfully")
        simplified_data = []
        for item in data:
            simplified_data.append({
                "sha": item["sha"],
                "state": state,
                "title": title,
                "user": user,
                "filename": item["filename"],
                "status": item["status"],
                "additions": item["additions"],
                "deletions": item["deletions"],
                "changes": item["changes"],
                "created_at":created,
                "updated_at":updated            })
        # append_to_json(simplified_data, "pull_request.json")
        print(simplified_data)
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")    
    except ValueError as e:
        print(f"Error parsing JSON: {e}")

# %%
def fetch_number_of_pr(repo_name,repo):
    url = f"https://api.github.com/repos/{repo_name}/{repo}/pulls"
    load_dotenv()
    bear_token = os.getenv('GITHUB_PERSONAL_ACCESS_TOKEN')

    headers = {
        "Authorization": f"Bearer {bear_token}",
        "Accept": "application/vnd.github.v3+json"
    }
    try: 
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an error for bad responses
        data = response.json()
        print(data)
        for i in data:
            fetch_and_post_pull_request_files(repo_name, repo, i['number'],i['state'],i['title'],i['user']['login'],i["created_at"],i["updated_at"])
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")    
    except ValueError as e:
        print(f"Error parsing JSON: {e}")
fetch_number_of_pr("dev-Rutwik", "Github_AI_Agent")
# Out:
# [{'url': 'https://api.github.com/repos/Dev-Rutwik/Github_AI_Agent/pulls/4', 'id': 2635542760, 'node_id': 'PR_kwDOPFBJ_s6dFzDo', 'html_url': 'https://github.com/Dev-Rutwik/Github_AI_Agent/pull/4', 'diff_url': 'https://github.com/Dev-Rutwik/Github_AI_Agent/pull/4.diff', 'patch_url': 'https://github.com/Dev-Rutwik/Github_AI_Agent/pull/4.patch', 'issue_url': 'https://api.github.com/repos/Dev-Rutwik/Github_AI_Agent/issues/4', 'number': 4, 'state': 'open', 'locked': False, 'title': '"Let the Data_harvestor branch have all main branch changes"', 'user': {'login': 'Dev-Rutwik', 'id': 215499842, 'node_id': 'U_kgDODNhEQg', 'avatar_url': 'https://avatars.githubusercontent.com/u/215499842?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Dev-Rutwik', 'html_url': 'https://github.com/Dev-Rutwik', 'followers_url': 'https://api.github.com/users/Dev-Rutwik/followers', 'following_url': 'https://api.github.com/users/Dev-Rutwik/following{/other_user}', 'gists_url': 'https://api.github.com/users/Dev-Rutwik/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Dev-Rutwik/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Dev-Rutwik/subscriptions', 'organizations_url': 'https://api.github.com/users/Dev-Rutwik/orgs', 'repos_url': 'https://api.github.com/users/Dev-Rutwik/repos', 'events_url': 'https://api.github.com/users/Dev-Rutwik/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Dev-Rutwik/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': None, 'created_at': '2025-07-02T13:55:27Z', 'updated_at': '2025-07-03T05:08:57Z', 'closed_at': None, 'merged_at': None, 'merge_commit_sha': None, 'assignee': None, 'assignees': [], 'requested_reviewers': [], 'requested_teams': [], 'labels': [], 'milestone': None, 'draft': False, 'commits_url': 'https://api.github.com/repos/Dev-Rutwik/Github_AI_Agent/pulls/4/commits', 'review_comments_url': 'https://api.github.com/repos/Dev-Rutwik/Github_AI_Agent/pulls/4/comments', 'review_comment_url': 'https://api.github.com/repos/Dev-Rutwik/Github_AI_Agent/pulls/comments{/number}', 'comments_url': 'https://api.github.com/repos/Dev-Rutwik/Github_AI_Agent/issues/4/comments', 'statuses_url': 'https://api.github.com/repos/Dev-Rutwik/Github_AI_Agent/statuses/376c2140e1f70f6c574bcbdd04617c68a48aa187', 'head': {'label': 'Dev-Rutwik:main', 'ref': 'main', 'sha': '376c2140e1f70f6c574bcbdd04617c68a48aa187', 'user': {'login': 'Dev-Rutwik', 'id': 215499842, 'node_id': 'U_kgDODNhEQg', 'avatar_url': 'https://avatars.githubusercontent.com/u/215499842?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Dev-Rutwik', 'html_url': 'https://github.com/Dev-Rutwik', 'followers_url': 'https://api.github.com/users/Dev-Rutwik/followers', 'following_url': 'https://api.github.com/users/Dev-Rutwik/following{/other_user}', 'gists_url': 'https://api.github.com/users/Dev-Rutwik/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Dev-Rutwik/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Dev-Rutwik/subscriptions', 'organizations_url': 'https://api.github.com/users/Dev-Rutwik/orgs', 'repos_url': 'https://api.github.com/users/Dev-Rutwik/repos', 'events_url': 'https://api.github.com/users/Dev-Rutwik/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Dev-Rutwik/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'repo': {'id': 1011894782, 'node_id': 'R_kgDOPFBJ_g', 'name': 'Github_AI_Agent', 'full_name': 'Dev-Rutwik/Github_AI_Agent', 'private': True, 'owner': {'login': 'Dev-Rutwik', 'id': 215499842, 'node_id': 'U_kgDODNhEQg', 'avatar_url': 'https://avatars.githubusercontent.com/u/215499842?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Dev-Rutwik', 'html_url': 'https://github.com/Dev-Rutwik', 'followers_url': 'https://api.github.com/users/Dev-Rutwik/followers', 'following_url': 'https://api.github.com/users/Dev-Rutwik/following{/other_user}',  ...
# Data Fetched Successfully
# [{'sha': 'e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', 'state': 'open', 'title': '"Let the Data_harvestor branch have all main branch changes"', 'user': 'Dev-Rutwik', 'filename': 'LangGraph/__init__.py', 'status': 'renamed', 'additions': 0, 'deletions': 0, 'changes': 0, 'created_at': '2025-07-02T13:55:27Z', 'updated_at': '2025-07-03T05:08:57Z'}, {'sha': '84600ec43f67acc2da3857d284160675d5d4b38a', 'state': 'open', 'title': '"Let the Data_harvestor branch have all main branch changes"', 'user': 'Dev-Rutwik', 'filename': 'LangGraph/__pycache__/__init__.cpython-310.pyc', 'status': 'added', 'additions': 0, 'deletions': 0, 'changes': 0, 'created_at': '2025-07-02T13:55:27Z', 'updated_at': '2025-07-03T05:08:57Z'}, {'sha': '1f2dca9ef530893027466a5e3829abcda32f6ce5', 'state': 'open', 'title': '"Let the Data_harvestor branch have all main branch changes"', 'user': 'Dev-Rutwik', 'filename': 'LangGraph/__pycache__/graph_builder.cpython-310.pyc', 'status': 'added', 'additions': 0, 'deletions': 0, 'changes': 0, 'created_at': '2025-07-02T13:55:27Z', 'updated_at': '2025-07-03T05:08:57Z'}, {'sha': '0255f99d257051713b9f2420fa69b203f0bcb982', 'state': 'open', 'title': '"Let the Data_harvestor branch have all main branch changes"', 'user': 'Dev-Rutwik', 'filename': 'LangGraph/graph_builder.py', 'status': 'added', 'additions': 42, 'deletions': 0, 'changes': 42, 'created_at': '2025-07-02T13:55:27Z', 'updated_at': '2025-07-03T05:08:57Z'}, {'sha': '252373da2786eaf1bd5e648339b8ed84bb29175a', 'state': 'open', 'title': '"Let the Data_harvestor branch have all main branch changes"', 'user': 'Dev-Rutwik', 'filename': 'README.md', 'status': 'modified', 'additions': 1, 'deletions': 99, 'changes': 100, 'created_at': '2025-07-02T13:55:27Z', 'updated_at': '2025-07-03T05:08:57Z'}, {'sha': 'e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', 'state': 'open', 'title': '"Let the Data_harvestor branch have all main branch changes"', 'user': 'Dev-Rutwik', 'filename': 'data/__init__.py', 'status': 'renamed', 'additions': 0, 'deletions': 0, 'changes': 0, 'created_at': '2025-07-02T13:55:27Z', 'updated_at': '2025-07-03T05:08:57Z'}, {'sha': '0ea447fd6985aef00229edafce3223a351a38a94', 'state': 'open', 'title': '"Let the Data_harvestor branch have all main branch changes"', 'user': 'Dev-Rutwik', 'filename': 'data/commits.json', 'status': 'added', 'additions': 104, 'deletions': 0, 'changes': 104, 'created_at': '2025-07-02T13:55:27Z', 'updated_at': '2025-07-03T05:08:57Z'}, {'sha': '686c70ae1c59851610a3576d2d980718ad7854af', 'state': 'open', 'title': '"Let the Data_harvestor branch have all main branch changes"', 'user': 'Dev-Rutwik', 'filename': 'data/data_fetcher.ipynb', 'status': 'removed', 'additions': 0, 'deletions': 125, 'changes': 125, 'created_at': '2025-07-02T13:55:27Z', 'updated_at': '2025-07-03T05:08:57Z'}, {'sha': 'e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', 'state': 'open', 'title': '"Let the Data_harvestor branch have all main branch changes"', 'user': 'Dev-Rutwik', 'filename': 'data/fake_github_events.json', 'status': 'removed', 'additions': 0, 'deletions': 0, 'changes': 0, 'created_at': '2025-07-02T13:55:27Z', 'updated_at': '2025-07-03T05:08:57Z'}, {'sha': 'e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', 'state': 'open', 'title': '"Let the Data_harvestor branch have all main branch changes"', 'user': 'Dev-Rutwik', 'filename': 'data/issues.json', 'status': 'renamed', 'additions': 0, 'deletions': 0, 'changes': 0, 'created_at': '2025-07-02T13:55:27Z', 'updated_at': '2025-07-03T05:08:57Z'}, {'sha': 'f1748006cdae857b09b0b3b5a52bb16d95dfe5f1', 'state': 'open', 'title': '"Let the Data_harvestor branch have all main branch changes"', 'user': 'Dev-Rutwik', 'filename': 'data/pull_request.json', 'status': 'added', 'additions': 14, 'deletions': 0, 'changes': 14, 'created_at': '2025-07-02T13:55:27Z', 'updated_at': '2025-07-03T05:08:57Z'}, {'sha': '5c3ea4b4b4696b077b91a59a16550ff219f6c886', 'state': 'open', 'title': '"Let the Data_harvestor branch have all main branch changes"', 'user': 'Dev ...
# Data Fetched Successfully
# [{'sha': 'e0a68adb7e2441e035cd370533930cc698745d2c', 'state': 'open', 'title': '"Pull this changes"', 'user': 'Dev-Rutwik', 'filename': 'data/data_fetcher.ipynb', 'status': 'modified', 'additions': 41, 'deletions': 5, 'changes': 46, 'created_at': '2025-07-02T05:16:44Z', 'updated_at': '2025-07-02T05:16:44Z'}]

# %%
from datetime import datetime, timedelta, time
from dateutil.parser import parse

WORK_START = time(9, 0)  # 9:00 AM
WORK_END = time(17, 0)   # 5:00 PM
WORK_DURATION = timedelta(hours=8)

def is_working_hours(dt):
    """Check if datetime falls within working hours"""
    return WORK_START <= dt.time() <= WORK_END
timestamps = [
    "2025-07-02T13:57:38Z",  # 1:57 PM - within work hours
    "2025-07-02T14:16:49Z",  # 2:16 PM - within work hours
    "2025-07-03T05:09:24Z"   # 5:09 AM - outside work hours
]

times = [parse(ts) for ts in timestamps]
extra_working_time = []
working_times = []
for dt in times:
    if is_working_hours(dt):
        working_times.append(dt)
    else:
        extra_working_time.append(dt)


print(f"Found {len(working_times)} events during working hours:")
for dt in working_times:
    print(f"- {dt.strftime('%Y-%m-%d %H:%M:%S')}")
for dt in extra_working_time:
    print(f"- Extra working hrs {dt.strftime('%Y-%m-%d %H:%M:%S')}")
if len(working_times) >= 2:
    deltas = []
    for i in range(1, len(working_times)):
        delta = working_times[i] - working_times[i-1]
        deltas.append(delta)
        print(f"\nInterval between work events {i} and {i+1}: {delta}")
    
    avg_delta = sum(deltas, timedelta(0)) / len(deltas)
    print(f"\nAverage work interval: {avg_delta}")
    print(f"Work frequency: every {avg_delta.total_seconds()/60:.1f} minutes during work hours")
else:
    print("\nNot enough working hour events to calculate frequency")
# Out:
# Found 2 events during working hours:
# - 2025-07-02 13:57:38
# - 2025-07-02 14:16:49
# - Extra working hrs 2025-07-03 05:09:24
#
# Interval between work events 1 and 2: 0:19:11
#
# Average work interval: 0:19:11
# Work frequency: every 19.2 minutes during work hours
